# %% [markdown]
# <p style="margin: 0;">
#   <!-- Left logo stays on the left -->
#   <img src="./Images/logo.png" alt="logo" width="280" style="margin-bottom: 0;" />
#
#   <!-- Right-aligned container -->
#   <span style="float: right; text-align: right;">
# <a href="https://aichemy.ac.uk/" target="_blank">
#   <img src="./Images/ai_chemy_logo.png"
#        alt="ai_chemy logo"
#        width="280"
#        style="margin-top: 20px; display: block;" />
# </a>
#     <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">
#       <img alt="Creative Commons Licence"
#            style="border-width: 0; margin-top: 10px; display: block;"
#            src="https://i.creativecommons.org/l/by/4.0/88x31.png"
#            title="This work is licensed under a Creative Commons Attribution 4.0 International License." />
#     </a>
#   </span>
# </p>
#
# <h1 style="margin-top: 0; text-align: center;">Session 2 Hill Equation - Pair Assignment</h1>
# <hr style="border: 1px solid black;">

# %% [markdown]
# This project has received funding from the AI for Chemistry: AIchemy Hub (EPSRC grant EP/Y028775/1 and EP/Y028759/1) and educational support from the <a href="https://github.com/Edinburgh-Chemistry-Teaching/Data-driven-chemistry">Data-Driven Chemistry</a>  course at the University of Edinburgh’s School of Chemistry.
#
# Authors:
#
# - Dr Alex Aziz
# - Mr Zhaohui Jiang
#
# Email: a.aziz@mmu.ac.uk
# <hr style="border: 1px solid black;">

# %% [markdown]
# <span style="font-weight: normal; font-size: 14px;">
# Work in pairs to complete this Jupyter Notebook. You are allowed to use AI tools, but you must include any AI commands used. Marks will be awarded as follows: <br>
#
# - Introduction (5%)
# - Notes on your code and understanding (30%)
# - Presentation (25%)
# - AI commands used (25%)
# - Conclusions (5%)
# - References and presentation (10%)
#
# Please submit this Jupyter Notebook with any accompanying files for this assignment.
# </span>

# %% [markdown]
# <span style='font-weight:bold; font-size:14px;'>You have been provided experimental Hill data.</span>
#
# <p style="font-size:12px;">
#
# The goals of this assessment are to
# - Deepen your understanding of the Hill equation and Hill plots.
# - Produce publication quality plots using the skills you have learnt during this semester.
# - Use AI tools to help you create a slider to see how the Hill plot changes as a function of the Ligand concentration ([$L$]), the dissociation constant (K$_d$), and the Hill coefficient ($n$).
# - Manipulate data to create a Hill plot.

# %% [markdown]
# <div class="alert alert-success" >
# <b>🔧 Task 1: Introduction. </b>
# </div>
#
# In the cell below, write a short introduction (~200 words) on the use of the Hill equation to analyze quantitative drug–receptor relationships. Include the Hill equation in LaTeX format and appropriate references. Make sure the cell is set to Markdown mode.

# %% [markdown]
# <div class="alert alert-success">
# <b>🔧 Task 2: In the previous session you defined a function for the Hill Equation. Import the function into this Notebook.</b>
# </div>
# Call the function with the following parameters L = 1, K$_d$ = 2.5, n = 3

# %% [markdown]
# <div class="alert alert-success">
# <b>🔧 Task 3: Import the following libraries.
# </div>

# %% [markdown]
# - numpy
# - matplotlib
# - pandas
# - curve_fit from scipy.optimize</b>

# %% [markdown]
# <div class="alert alert-success">
# <b>🔧 Task 4: Extract the experimental data located in the data folder corresponding to your group, and rename the columns. </b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>🔧 Group 1. </b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>🔧 Task 5: Extract the column values and plot the experimental data.</b>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Note:</b>
#
# The Hill equation is used to model cooperative binding. As the Hill coefficient increases, the saturation curve becomes steeper. To visualize this, the concentration is often presented on a logarithmic scale.

# %% [markdown]
# <div class="alert alert-success">
# <b>🔧 Task 6: Data manipulation and fitting.</b>
# </div>
#
# - Convert the ligand concentration to a log$_{10}$ scale.
# - Convert the ligand binding concentration to the bound fraction.
# - Fit your specified group's data to determine the Hill coefficient.
# - Plot the data

# %% [markdown]
# <div class="alert alert-success">
# <b>🔧 Task 7: Use GenAI to create a slider that shows how variations in the parameters affect the bound concentration in the Hill equation.</b>
# </div>
#
# - In a Markdown cell, include any GenAI commands you used.
# - Use comments to clearly explain your code.

# %% [markdown]
# <div class="alert alert-success">
# <b>🔧 Task 8: Create a Hill plot from your given data, determine the intercept and slope.</b>
# </div>
# The Hill plot is the rearrangement of the Hill equation into a linear plot with the gradient being the Hill coefficient and the intercept being equal to -$n$log$K_d$.
#
# - Determine the Hill coefficient and $K_d$ from your data
# - Discuss whether you Hill coefficient is representative of co-orperative or non-cooperative binding
# - Comment on any discrepancy between the two methods used to calculate the Hill coefficient and $K_d$

# %% [markdown]
# <span style='font-weight:bold; font-size:20px;'>Conclusions</span>

# %% [markdown]
# <span style='font-weight:bold; font-size:20px;'>References</span>
